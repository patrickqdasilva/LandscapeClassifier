# %% [markdown]
# # Deep Learning Model for Classifying Landscape
# ###  Patrick Da Silva
# * This notebook will walk through the steps from from image collection to deploying the model.
# * The model is fed aerial images of rural and suburban landscapes.
# * Given novel images, the model will be able to fit the photo into each class accordingly.
# * I use an extensive amount of comments in this project to aid in my learning and to make sure I understand exactly what each step is doing.
# * This image classification model pipeline was inspired by Nicholas Renotte

# %% [markdown]
# ## 1 Environment Setup and Data Acquisition

# %% [markdown]
# #### Installing Dependencies on Environment

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (2.10.0)
# Requirement already satisfied: tensorflow-gpu in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (2.10.0)
# Requirement already satisfied: opencv-python in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (3.6.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: packaging in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.49.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.12.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\patrick\gymnasticsdl\gymdl\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# WARNING: You are using pip version 21.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Patrick\GymnasticsDL\gymDL\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
#Check to make sure everything installed properly
# !pip list
# Out:
# Package                      Version
# ---------------------------- ---------
# absl-py                      1.2.0
# asttokens                    2.0.8
# astunparse                   1.6.3
# backcall                     0.2.0
# cachetools                   5.2.0
# certifi                      2022.9.24
# charset-normalizer           2.1.1
# colorama                     0.4.5
# contourpy                    1.0.5
# cycler                       0.11.0
# debugpy                      1.6.3
# decorator                    5.1.1
# entrypoints                  0.4
# executing                    1.1.0
# flatbuffers                  22.9.24
# fonttools                    4.37.4
# gast                         0.4.0
# google-auth                  2.12.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.49.1
# h5py                         3.7.0
# idna                         3.4
# importlib-metadata           4.12.0
# ipykernel                    6.16.0
# ipython                      8.5.0
# jedi                         0.18.1
# jupyter_client               7.3.5
# jupyter-core                 4.11.1
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.4
# libclang                     14.0.6
# Markdown                     3.4.1
# MarkupSafe                   2.1.1
# matplotlib                   3.6.0
# matplotlib-inline            0.1.6
# nest-asyncio                 1.5.6
# numpy                        1.23.3
# oauthlib                     3.2.1
# opencv-python                4.6.0.66
# opt-einsum                   3.3.0
# packaging                    21.3
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.2.0
# pip                          21.2.3
# prompt-toolkit               3.0.31
# protobuf                     3.19.6
# psutil                       5.9.2
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# Pygments                     2.13.0
# pyparsing                    3.0.9
# python-dateutil              2.8.2
# pywin32                      304
# pyzmq                        24.0.1
# requests                     2.28.1
# requests-oauthlib            1.3.1
# rsa                          4.9
# setuptools                   57.4.0
# six                          1.16.0
# stack-data                   0.5.1
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.0
# tensorflow-estimator         2.10.0
# tensorflow-gpu               2.10.0
# tensorflow-io-gcs-filesystem 0.27.0
# termcolor                    2.0.1
# tornado                      6.2
# traitlets                    5.4.0
# typing_extensions            4.3.0
# urllib3                      1.26.12
# wcwidth                      0.2.5
# Werkzeug                     2.2.2
# wheel                        0.37.1
# wrapt                        1.14.1
# zipp                         3.8.1
# WARNING: You are using pip version 21.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Patrick\GymnasticsDL\gymDL\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import os

# %%
#Avoid out of memory errors by setting limit on GPU Memory Consumption Growth

#Finding the gpu in my machine (I only have 1, but this would work if you had multiple)
gpus = tf.config.experimental.list_physical_devices('GPU')
#Tensorflow will keep memory usage to the bare minimum
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# #### Remove Corrupt Images

# %%
import cv2
import imghdr #package to check file extensions

# %%
data_dir   =  'data'
image_exts = ['jpeg','jpg','bmp','png']

# %%
#loop through each folder in data directory (our two classes we want to distinguish between)
for image_class in os.listdir(data_dir):
    #Loop thorugh every image within each class type
    for image in os.listdir(os.path.join(data_dir, image_class)):
        #individual image path
        image_path = os.path.join(data_dir, image_class, image)
        try:
            #make sure image can be read in by OpenCV
            img = cv2.imread(image_path)
            #the extension of each image
            ext = imghdr.what(image_path)
            #if the image extension is not in the preapproved list, delete the image
            if ext not in image_exts:
                print(f'Image not in preapproved extension list {image_path}')
                os.remove(image_path)
        #catch any errors and print out error message
        except Exception as e:
            print(f'ERROR: Issue with image {image_path}')
            # os.remove(image_path) -> only uncomment this if you want to actually want to delete the errors

# %% [markdown]
# #### Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#Step 1: Build data pipeline
#since our data is split into two folders, this function will take care of many preprocessing tasks
# (batch_size = 32, image_size(256,256), shuffle=True, labels='inferred' by DEFAULT)
data = tf.keras.utils.image_dataset_from_directory(data_dir)

#Step 2: Access data pipeline
#Use this to get consecutive batches
data_iterator = data.as_numpy_iterator()

#Step 3: Grab a single batch
#Each batch will have 2 components, 1 - images loaded into memory as np array, 2 - class labels
batch = data_iterator.next()
# Out:
# Found 1421 files belonging to 2 classes.

# %%
#Print some example images, also figure out which label corresponds to which class - written by Nicholas Renotte
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
    
#Rural = 0
#Suburban = 1

# %% [markdown]
# ## 2 Data Preprocessing

# %% [markdown]
# #### Scale Data

# %%
#when each batch is loaded, scale the values in the 3 color channels to be between 0 and 1
scaled_data = data.map(lambda x, y: (x/255, y))

# %% [markdown]
# #### Split Data

# %%
#Split the data into train, validation, and test
#Training data - make the model and learn hidden features
train_size = int(len(scaled_data)*.8)+1 #37 atches of 32 images
#Validation data - validate model performance and tune hyperparameters
val_size   = int(len(scaled_data)*.1) #4 batches of 32 images
#Test data - evaluate model after training is completed
test_size  = int(len(scaled_data)*.1) #4 batches of 32 images

# %%
#Data already shuffled - take the values correpsonding to the number of batches for each data set
train = scaled_data.take(train_size) #23 batches of 32 images
val   = scaled_data.skip(train_size).take(val_size) #7 batches of 32 images
test  = scaled_data.skip(train_size+val_size).take(test_size) # 4 batches of 32 images

# %% [markdown]
# ## 3 Deep Model

# %% [markdown]
# #### Build Keras Sequential Deep Learning Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense, BatchNormalization, InputLayer

# %%
model = Sequential()

### Start Preprocessing/Data Augmentation ###
model.add(InputLayer(input_shape=(256,256,3)))
#Horizontal flip is unlikely to influence our image, therefore we apply this transformation to effectively train on more images
model.add(preprocessing.RandomFlip('horizontal')) # flip left to right
### End Preprocessing/Data Augmentation ###

### Start Base/Convolution/Feature Extraction ###
#First Block
#Start with larger kernel for dimensionality reduction
model.add(BatchNormalization())
model.add(Conv2D(16, (5,5), 1, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))
#Second Block
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), 1, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))
#Third Block
model.add(Conv2D(16, (3,3), 1, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))
### End Base/Convolution/Feature Extraction ###

### Start Head/Classification ###
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(units=256, activation='relu'))
#Add dropout to help prevent overfitting
model.add(Dropout(rate=0.3))
model.add(BatchNormalization())
model.add(Dense(units=1, activation='sigmoid'))
### End Head/Classification ###

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), #optimizer - adjusts the weights to minimize the loss (adam is a SGD optimizer with an adaptive learning rate
    loss='binary_crossentropy', #loss - compares the predicted probability  with the actual output then calculates error based on the distance from the expected value
    metrics=['accuracy'], #metrics - how well the model is classifying data
)

# %% [markdown]
# #### Train Model

# %%
from tensorflow.keras.callbacks import EarlyStopping
#Stop training when validation loss starts to increase
early_stopping = EarlyStopping(
    min_delta=0.01,  #minimum amount of change to count as improvement
    patience=20,     #how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
#For Reproducability
tf.random.set_seed(31415)
np.random.seed(31415)
history = model.fit(
    train,               #training dataset - #28 batches of 32 images
    validation_data=val, #validation dataset - #3 batches of 32 images
    epochs=50,           #number of runs through entire training dataset
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 12s 228ms/step - loss: 0.5127 - accuracy: 0.8581 - val_loss: 2.9212 - val_accuracy: 0.4297
# Epoch 2/50
# 37/37 [==============================] - 8s 200ms/step - loss: 0.2265 - accuracy: 0.9147 - val_loss: 3.8142 - val_accuracy: 0.5078
# Epoch 3/50
# 37/37 [==============================] - 8s 200ms/step - loss: 0.1867 - accuracy: 0.9358 - val_loss: 3.6814 - val_accuracy: 0.5078
# Epoch 4/50
# 37/37 [==============================] - 8s 208ms/step - loss: 0.1350 - accuracy: 0.9527 - val_loss: 4.3012 - val_accuracy: 0.4375
# Epoch 5/50
# 37/37 [==============================] - 8s 206ms/step - loss: 0.1365 - accuracy: 0.9561 - val_loss: 3.6412 - val_accuracy: 0.4375
# Epoch 6/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0763 - accuracy: 0.9730 - val_loss: 2.8279 - val_accuracy: 0.4688
# Epoch 7/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0507 - accuracy: 0.9890 - val_loss: 1.8088 - val_accuracy: 0.5547
# Epoch 8/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0452 - accuracy: 0.9882 - val_loss: 1.5240 - val_accuracy: 0.5547
# Epoch 9/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0344 - accuracy: 0.9899 - val_loss: 0.6554 - val_accuracy: 0.7188
# Epoch 10/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0281 - accuracy: 0.9899 - val_loss: 0.7112 - val_accuracy: 0.6953
# Epoch 11/50
# 37/37 [==============================] - 8s 214ms/step - loss: 0.0307 - accuracy: 0.9924 - val_loss: 0.2600 - val_accuracy: 0.8672
# Epoch 12/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.0523 - val_accuracy: 0.9844
# Epoch 13/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 14/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 15/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 16/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 17/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0087 - accuracy: 0.9992 - val_loss: 0.0136 - val_accuracy: 0.9922
# Epoch 18/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0160 - accuracy: 0.9932 - val_loss: 0.0214 - val_accuracy: 0.9922
# Epoch 19/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 20/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 21/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0099 - accuracy: 0.9992 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 22/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 23/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 24/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 25/50
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 26/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 27/50
# 37/37 [==============================] - 8s 209ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 28/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 29/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 4.6545e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 37/37 [==============================] - 8s 201ms/step - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 31/50
# 37/37 [==============================] - 8s 203ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.5941e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 5.0483e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.4729e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 37/37 [==============================] - 8s 201ms/step - loss: 7.2569e-04 - accuracy: 1.0000 - val_loss: 2.0397e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3019e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 37/37 [==============================] - 8s 202ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 3.1085e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 37/37 [==============================] - 8s 211ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0584 - val_accuracy: 0.9766
# Epoch 38/50
# 37/37 [==============================] - 8s 210ms/step - loss: 0.0712 - accuracy: 0.9738 - val_loss: 0.3427 - val_accuracy: 0.9375
# Epoch 39/50
# 37/37 [==============================] - 8s 207ms/step - loss: 0.0643 - accuracy: 0.9780 - val_loss: 0.0823 - val_accuracy: 0.9688
# Epoch 40/50
# 37/37 [==============================] - 8s 206ms/step - loss: 0.0665 - accuracy: 0.9721 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 41/50
# 37/37 [==============================] - 8s 211ms/step - loss: 0.0201 - accuracy: 0.9949 - val_loss: 0.0600 - val_accuracy: 0.9688
# Epoch 42/50
# 37/37 [==============================] - 8s 205ms/step - loss: 0.0153 - accuracy: 0.9975 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 43/50
# 37/37 [==============================] - 8s 212ms/step - loss: 0.0131 - accuracy: 0.9983 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 44/50
# 37/37 [==============================] - 8s 203ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 45/50
# 37/37 [==============================] - 8s 207ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0014 - val_accuracy: 1.0000

# %% [markdown]
# #### Plot Performance

# %%
#The model displayed layer by layer with several metrics
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip (RandomFlip)    (None, 256, 256, 3)       0
#
#  batch_normalization (BatchN  (None, 256, 256, 3)      12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      1216
#
#  max_pooling2d (MaxPooling2D  (None, 256, 256, 16)     0
#  )
#
#  batch_normalization_1 (Batc  (None, 256, 256, 16)     64
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 16)      4624
#
#  max_pooling2d_2 (MaxPooling  (None, 256, 256, 16)     0
#  2D)
#
#  flatten (Flatten)           (None, 1048576)           0
#
#  batch_normalization_2 (Batc  (None, 1048576)          4194304
#  hNormalization)
#
#  dense (Dense)               (None, 256)               268435712
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 272,641,853
# Trainable params: 270,544,151
# Non-trainable params: 2,097,702
# _________________________________________________________________

# %%
#Plotting loss and validation loss across epochs
loss_eval = plt.figure()
plt.ylim(0,1)
plt.plot(history.history['loss'], color='#0C7BDC', label='loss')
plt.plot(history.history['val_loss'], color='#FFC20A', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
loss_eval.suptitle('Loss', fontsize=15)
plt.legend(loc='upper right')
plt.show()

# %%
#Plotting accuracy and validation accuracy across epcohs
acc_eval = plt.figure()
plt.plot(history.history['accuracy'], color='#0C7BDC', label='accuracy')
plt.plot(history.history['val_accuracy'], color='#FFC20A', label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
acc_eval.suptitle('Accuracy', fontsize=15)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4 Evaluate Performance

# %% [markdown]
# #### Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
#establish instances of the metrics
precision    = Precision()      # (TruePos)/(TruePos+FalsePos) -> model's ability to calssify something as positive
recall       = Recall()         # (TruePos)/(TruePos+FalseNeg) -> model's ability to detect positive samples
binAccuracy  = BinaryAccuracy() # (TruePos + TrueNeg)/all -> number of correct predictions divided by all predictions

# %%
#loop through each batch in the testing dataset - 3 batches with 32 images each
for batch in test.as_numpy_iterator():
    #X is the images, y is the true value of 1s and 0s
    X, y = batch
    yhat = model.predict(X)
    precision.update_state(y, yhat) 
    recall.update_state(y, yhat)    
    binAccuracy.update_state(y,yhat)
# Out:
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 244ms/step

# %%
print(f'Precision = {precision.result()}')
print(f'Recall = {recall.result()}')
print(f'Binary Accuracy = {binAccuracy.result()}')
# Out:
# Precision = 1.0
# Recall = 1.0
# Binary Accuracy = 1.0

# %% [markdown]
# #### Showing Off: Visualizing Testing with Single Images Outside of Dataset

# %%
#Show off model by testing on a single image outside of dataset
#Load image
image = cv2.imread('RTest.jpg')
#Switch color values from BGR to RGB
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(image, (256,256))
#predict class with the model
yhat = model.predict(np.expand_dims(resize/255, 0))
print(f'yhat = {yhat}')
# Out:
# 1/1 [==============================] - 0s 70ms/step
# yhat = [[0.14564973]]

# %%
#Display which class the model chose for the image
if yhat > 0.5:
    print('Predicted class is Suburban')
else:
    print('Predicted class is Rural')
# Out:
# Predicted class is Rural

# %% [markdown]
# ## 5 Save Model for Future Use

# %%
model.save(os.path.join('models','landscapeClass.h5'))

# %% [markdown]
# ## 6 Conclusions
#
# #### Model Evaluation
#  - The model completed the classifying task with flying colors! All three of our metrics are as good as they could be on our testing data. <br>
#     - Recall that -> *Precision = 1.0, Recall = 1.0, Binary Accuracy = 1.0*
#
# #### Limitations
# - The dataset was compiled from a quick google search, therefore our model is likely not as robust as it could be.
#
# #### Questions/Concerns
# - The model has 272 million total parameters, 2 million of which are untrainable (It seems the number of parameters is unusually large). I will investigate why this is the case and improve the model accordingly.
# <br>
# - Both validation loss and validation accuracy started very far away from the training loss and training accuracy, but quickly converged.
#
# #### Future Direction
# 1. Implement categorical classification with other landscapes (cities, desserts, oceans, forests, etc.)
# 2. Integrate with a video feed to allow real time updates of landscape
# 3. This model can also be improved by reducing the number of parameters while keeping the Precision, Recall, and Accuracy high. Reduce running cost and time
